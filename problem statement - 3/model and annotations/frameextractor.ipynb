# %%
import cv2
import os

def extract_frames(video_path, output_folder, num_frames=200):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Open the video file
    cap = cv2.VideoCapture(video_path)

    # Get the total number of frames
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the frame interval to get the desired number of frames
    frame_interval = max(total_frames // num_frames, 1)

# %%
# Install necessary libraries
# !pip install opencv-python

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-3-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     131   )
#     132   if ephemeral:
# --> 133     _message.blocking_request(
#     134         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
# ...

# %%
import cv2
import os

def extract_frames(video_path, output_folder, num_frames=100):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Open the video file
    cap = cv2.VideoCapture(video_path)

    # Get the total number of frames
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the frame interval to get the desired number of frames
    frame_interval = max(total_frames // num_frames, 1)

    # Loop through the frames and save the selected frames
    frame_count = 0
    while frame_count < num_frames:
        ret, frame = cap.read()
                # Break the loop if no more frames are available
        if not ret:
            break

        # Save frames at the specified interval
        if frame_count % frame_interval == 0:
            frame_filename = os.path.join(output_folder, f"frame1_{frame_count}.jpg")
            cv2.imwrite(frame_filename, frame)
            print(f"Frame {frame_count} saved")

        frame_count += 1

    # Release the video capture object
    cap.release()

# %%
# Example usage
video_path = "/content/drive/MyDrive/what ra sudeep?/ps-1/output_video (1).mp4"
output_folder = "/content/drive/MyDrive/what ra sudeep?/ps-1 frames"
num_frames = 2800

extract_frames(video_path, output_folder, num_frames)
# Out:
# Frame 0 saved
# Frame 4 saved
# Frame 8 saved
# Frame 12 saved
# Frame 16 saved
# Frame 20 saved
# Frame 24 saved
# Frame 28 saved
# Frame 32 saved
# Frame 36 saved
# Frame 40 saved
# Frame 44 saved
# Frame 48 saved
# Frame 52 saved
# Frame 56 saved
# Frame 60 saved
# Frame 64 saved
# Frame 68 saved
# Frame 72 saved
# Frame 76 saved
# Frame 80 saved
# Frame 84 saved
# Frame 88 saved
# Frame 92 saved
# Frame 96 saved
# Frame 100 saved
# Frame 104 saved
# Frame 108 saved
# Frame 112 saved
# Frame 116 saved
# Frame 120 saved
# Frame 124 saved
# Frame 128 saved
# Frame 132 saved
# Frame 136 saved
# Frame 140 saved
# Frame 144 saved
# Frame 148 saved
# Frame 152 saved
# Frame 156 saved
# Frame 160 saved
# Frame 164 saved
# Frame 168 saved
# Frame 172 saved
# Frame 176 saved
# Frame 180 saved
# Frame 184 saved
# Frame 188 saved
# Frame 192 saved
# Frame 196 saved
# Frame 200 saved
# Frame 204 saved
# Frame 208 saved
# Frame 212 saved
# Frame 216 saved
# Frame 220 saved
# Frame 224 saved
# ...
